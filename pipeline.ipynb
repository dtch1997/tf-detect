# %% [markdown]
# First, train the model

# %%
! python src/train_regression_model.py --dataset crowdhuman --epochs 25 --alpha 0.25 --input-size 96
# Out:
# 2020-08-27 06:43:44.386719: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-27 06:43:45.710035: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-27 06:43:45.713906: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-27 06:43:45.714380: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-08-27 06:43:45.714446: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %% [markdown]
# Convert the model to TFLite format

# %%
! python src/convert_tf_model_to_tf_lite.py \
    --model-name small_backbone_experimental \
    --dataset crowdhuman_debug \
    --num-samples 100 \
    --input-height 320 \
    --input-width 240
# Out:
# 2020-08-30 14:29:08.908949: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-08-30 14:29:10.982651: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-30 14:29:10.986394: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-30 14:29:10.986789: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-08-30 14:29:10.986837: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
! xxd -i exported_models/small_backbone_experimental/model.tflite > exported_models/small_backbone_experimental/model_data.cc
